# %% [markdown]
# # 1️⃣ Training an Adapter for a Transformer model
#
# In this notebook, we train an adapter for a **RoBERTa** ([Liu et al., 2019](https://arxiv.org/pdf/1907.11692.pdf)) model for sequence classification on a **sentiment analysis** task using [adapter-transformers](https://github.com/Adapter-Hub/adapter-transformers), the _AdapterHub_ adaptation of HuggingFace's _transformers_ library.
#
# If you're unfamiliar with the theoretical parts of adapters or the AdapterHub framework, check out our [introductory blog post](https://adapterhub.ml/blog/2020/11/adapting-transformers-with-adapterhub/) first.
#
# We train a **Task Adapter** for a pre-trained model here. Most of the code is identical to a full finetuning setup using HuggingFace's transformers. For comparison, have a look at the [same guide using full finetuning](https://colab.research.google.com/drive/1brXJg5Mokm8h3shxqPRnoIsRwHQoncus?usp=sharing).
#
# For training, we use the [movie review dataset by Pang and Lee (2005)](http://www.cs.cornell.edu/people/pabo/movie-review-data/). It contains movie reviews  from Rotten Tomatoes which are either classified as positive or negative. We download the dataset via HuggingFace's [datasets](https://github.com/huggingface/datasets) library.

# %% [markdown]
# ## Installation
#
# First, let's install the required libraries:

# %%
# !pip install -U adapter-transformers
# !pip install datasets
# Out:
# Requirement already satisfied: adapter-transformers in /usr/local/lib/python3.7/dist-packages (2.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from adapter-transformers) (21.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from adapter-transformers) (0.0.46)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from adapter-transformers) (4.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from adapter-transformers) (2.23.0)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from adapter-transformers) (0.10.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from adapter-transformers) (3.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from adapter-transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from adapter-transformers) (1.19.5)
# Requirement already satisfied: huggingface-hub>=0.0.17 in /usr/local/lib/python3.7/dist-packages (from adapter-transformers) (0.2.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from adapter-transformers) (4.62.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from adapter-transformers) (2019.12.20)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.0.17->adapter-transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->adapter-transformers) (3.0.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->adapter-transformers) (3.6.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->adapter-transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->adapter-transformers) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->adapter-transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->adapter-transformers) (2.10)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->adapter-transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->adapter-transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->adapter-transformers) (1.15.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (1.16.1)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2021.11.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.8.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.1.5)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (3.0.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.62.3)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.2.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.19.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.4)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.6)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (5.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.7.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.8)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)

# %% [markdown]
# ## Dataset Preprocessing
#
# Before we start to train our adapter, we first prepare the training data. Our training dataset can be loaded via HuggingFace `datasets` using one line of code:

# %%
from datasets import load_dataset, DatasetDict

dataset = load_dataset("yxchar/sciie-tlm")
dataset.num_rows
# Out:
# Using custom data configuration yxchar___sciie-tlm-a32f1f2c4e9b5c0d
# Reusing dataset csv (/root/.cache/huggingface/datasets/csv/yxchar___sciie-tlm-a32f1f2c4e9b5c0d/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a)
#   0%|          | 0/3 [00:00<?, ?it/s]
# {'test': 974, 'train': 3219, 'validation': 455}

# %% [markdown]
# Every dataset sample has an input text and a binary label:

# %%
max([len(x['text']) for x in dataset['train']])
# Out:
# 577

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'text', 'id', 'label'],
#         num_rows: 3219
#     })
#     test: Dataset({
#         features: ['Unnamed: 0', 'text', 'id', 'label'],
#         num_rows: 974
#     })
#     validation: Dataset({
#         features: ['Unnamed: 0', 'text', 'id', 'label'],
#         num_rows: 455
#     })
# })

# %% [markdown]
# Now, we need to encode all dataset samples to valid inputs for our Transformer model. Since we want to train on `roberta-base`, we load the corresponding `RobertaTokenizer`. Using `dataset.map()`, we can pass the full dataset through the tokenizer in batches:

# %%
from transformers import RobertaTokenizer

tokenizer = RobertaTokenizer.from_pretrained("roberta-base")

def encode_batch(batch):
  """Encodes a batch of input data using the model tokenizer."""
  return tokenizer(batch["text"], max_length=512, truncation=True, padding="max_length")

# Encode the input data
dataset = dataset.map(encode_batch, batched=True)
# The transformers model expects the target class column to be named "labels"
dataset.rename_column_("label", "labels")
# Transform to pytorch tensors and only output the required columns
dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
# Out:
# Loading cached processed dataset at /root/.cache/huggingface/datasets/csv/yxchar___sciie-tlm-a32f1f2c4e9b5c0d/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a/cache-1170b94b10923d12.arrow
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: FutureWarning: rename_column_ is deprecated and will be removed in the next major version of datasets. Use DatasetDict.rename_column instead.
#   if sys.path[0] == '':

# %% [markdown]
# Now we're ready to train our model...

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'attention_mask', 'id', 'input_ids', 'labels', 'text'],
#         num_rows: 3219
#     })
#     test: Dataset({
#         features: ['Unnamed: 0', 'attention_mask', 'id', 'input_ids', 'labels', 'text'],
#         num_rows: 974
#     })
#     validation: Dataset({
#         features: ['Unnamed: 0', 'attention_mask', 'id', 'input_ids', 'labels', 'text'],
#         num_rows: 455
#     })
# })

# %% [markdown]
# ## Training
#
# We use a pre-trained RoBERTa model from HuggingFace. We use `RobertaModelWithHeads`, a class unique to `adapter-transformers`, which allows us to add and configure prediction heads in a flexibler way.

# %%
import numpy as np

# %%
np.unique(dataset['train']['labels'])
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
from transformers import RobertaConfig, RobertaModelWithHeads

config = RobertaConfig.from_pretrained(
    "roberta-base",
    num_labels=7,
)
model = RobertaModelWithHeads.from_pretrained(
    "roberta-base",
    config=config,
)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModelWithHeads: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias']
# - This IS expected if you are initializing RobertaModelWithHeads from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModelWithHeads from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModelWithHeads were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# **Here comes the important part!**
#
# We add a new adapter to our model by calling `add_adapter()`. We pass a name (`"rotten_tomatoes"`) and [the type of adapter](https://docs.adapterhub.ml/adapters.html#adapter-types) (task adapter). Next, we add a binary classification head. It's convenient to give the prediction head the same name as the adapter. This allows us to activate both together in the next step. The `train_adapter()` method does two things:
#
# 1. It freezes all weights of the pre-trained model so only the adapter weights are updated during training.
# 2. It activates the adapter and the prediction head such that both are used in every forward pass.

# %%
model.load_adapter("/content/final_adapter")
# Out:
# 'sciie'

# %%
# # Add a new adapter
# model.add_adapter("sciie")
# # Add a matching classification head
# model.add_classification_head(
#     "sciie",
#     num_labels=7,
#     # id2label={ 0: "👎", 1: "👍"}
#   )

# # Activate the adapter
# model.train_adapter("sciie")

# %%
adapter_name = model.load_adapter("/content/final_adapter")

model.set_active_adapters(adapter_name)
# Out:
# Overwriting existing adapter 'sciie'.
# Overwriting existing head 'sciie'

# %%
import torch
device='cuda'

# %%
test_dataset = dataset['test']
bsz = 16
i = 0
batches = []
while i<test_dataset.num_rows:
  batches.append(test_dataset[i:i+bsz])
  i+=bsz

# %%
# Put model in evaluation mode
model.to(device)
model.eval()


# Tracking variables for storing ground truth and predictions 
predictions , true_labels = [], []

# Prediction Loop
for batch in batches:

 
 
  # Unpack the inputs from our dataloader and move to GPU/accelerator 
 
  input_ids = batch['input_ids'].to(device)
  attention_mask = batch['attention_mask'].to(device)
  labels = batch['labels'].to(device)

  
  # Telling the model not to compute or store gradients, saving memory and 
  # speeding up prediction
  with torch.no_grad():
      # Forward pass, calculate logit predictions
      outputs = model(input_ids, attention_mask=attention_mask, 
                         labels=labels)

  logits = outputs[1]

  # Move logits and labels to CPU
  logits = logits.detach().cpu().numpy()
  label_ids = labels.to('cpu').numpy()
  
  # Store predictions and true labels
  predictions.append(logits)
  true_labels.append(label_ids)

# %%
predictions
# Out:
# [array([[-1.8884428 ,  0.1050658 , -0.7264077 ,  3.2858791 ,  3.100538  ,
#          -4.3508964 , -0.60108906],
#         [-1.2388635 ,  2.5230796 , -2.715296  ,  3.9984171 ,  4.7768316 ,
#          -4.4296246 , -3.981271  ],
#         [-2.971092  ,  1.7569726 , -3.2996414 ,  5.138061  ,  2.7759657 ,
#          -4.9823833 ,  0.5523543 ],
#         [-2.643563  , -0.43135262, -1.0583457 ,  4.458822  ,  1.0931156 ,
#          -3.330486  ,  0.392027  ],
#         [-2.351655  , -2.3277557 , -3.5022995 ,  7.9692497 , -0.76124746,
#           0.73324275, -0.26425788],
#         [-2.75016   ,  1.2060477 , -4.0436044 ,  7.8976936 , -0.4114193 ,
#          -3.7191281 ,  0.657977  ],
#         [-5.0352163 ,  2.5033891 , -1.242385  ,  4.7942786 , -0.57123315,
#          -4.5497103 ,  2.7803087 ],
#         [-5.148657  ,  3.4410336 , -2.0782764 ,  4.8292174 ,  0.13492694,
#          -4.656694  ,  2.3420086 ],
#         [-1.7422447 , -2.3740318 , -4.0334535 ,  8.089609  , -1.2591072 ,
#           0.0239407 ,  0.5522504 ],
#         [ 0.5121365 , -0.6946108 ,  8.127147  , -2.575626  , -0.06911629,
#          -1.2271708 , -4.876681  ],
#         [-0.4643335 ,  2.955793  , -2.228901  ,  2.029986  ,  4.3307204 ,
#          -3.976289  , -3.691973  ],
#         [-1.3937947 , -0.94091517, -2.2008631 ,  7.5840096 ,  0.5295936 ,
#          -1.4048901 , -3.848205  ],
#         [ 1.1239713 , -1.8795861 ,  4.7337413 , -0.39317414,  1.2453463 ,
#          -1.453325  , -4.403543  ],
#         [ 8.62824   , -2.3224876 ,  0.42094514, -1.8635846 , -1.4775223 ,
#           1.790543  , -4.357916  ],
#         [ 2.9412687 , -2.0834944 ,  4.043963  , -0.26656425,  0.03705819,
#          -1.0479432 , -4.2253776 ],
#         [-1.5892546 , -1.8191066 , -2.110428  ,  8.162569  , -2.029809  ,
#          -1.1332549 , -0.5175453 ]], dtype=float32),
#  array([[-1.1440915e+00, -1.1847242e+00, -2.5496480e+00,  8.3618860e+00,
#          -3.3305639e-01, -2.4736772e+00, -2.2424200e+00],
#         [-3.6306002e+00,  5.8946365e-01, -1.6793506e+00,  7.0576949e+00,
#           1.0539107e+00, -3.3497448e+00, -1.3861877e+00],
#         [-1.8095746e+00,  1.7632751e-01, -4.0803704e+00,  9.1558952e+00,
#           2.5890014e-01, -2.8831389e+00, -1.8893808e+00],
#         [ 5.7105494e-01,  1.4036331e+00, -3.7176619e+00,  1.8989865e+00,
#           6.7897797e+00, -3.8313789e+00, -4.2274733e+00],
#         [-2.7424371e-01,  1.4912632e-02, -5.3391232e+00,  7.2283425e+00,
#          -1.9943743e+00,  1.1775866e+00, -1.4686506e+00],
#           3.6007464 , -3.941511  ],
#         [-0.6996241 ,  0.24304952, -4.667755  ,  8.172159  , -0.6847059 ,
#          -2.8106644 , -0.04671293],
#         [ 0.5002164 , -2.9817262 ,  6.031817  ,  0.8612245 , -2.62828   ,
#           0.08409411, -2.4237926 ],
#         [ 8.850309  , -2.082132  , -0.1438411 , -1.0593673 , -2.4659305 ,
#           1.9298526 , -4.2804475 ],
#         [ 2.0150073 , -3.353065  ,  5.931579  ,  0.01638063, -2.9312382 ,
#           0.6435676 , -2.8714561 ],
#         [-0.4304255 , -2.6654866 , -2.473705  ,  0.6691612 , -3.7329657 ,
#           6.981895  ,  1.2982107 ]], dtype=float32)]

# %% [markdown]
# For training, we make use of the `Trainer` class built-in into `transformers`. We configure the training process using a `TrainingArguments` object and define a method that will calculate the evaluation accuracy in the end. We pass both, together with the training and validation split of our dataset, to the trainer instance.
#
# **Note the differences in hyperparameters compared to full finetuning.** Adapter training usually required a few more training epochs than full finetuning.

# %%
import torch, gc

gc.collect()
torch.cuda.empty_cache()

# %%
import numpy as np
from transformers import TrainingArguments, AdapterTrainer, EvalPrediction

training_args = TrainingArguments(
    learning_rate=2*1e-5,
    num_train_epochs=30,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    logging_steps=200,
    output_dir="./training_output",
    overwrite_output_dir=True,
    # The next line is important to ensure the dataset labels are properly passed to the model
    remove_unused_columns=False,
)

def compute_accuracy(p: EvalPrediction):
  preds = np.argmax(p.predictions, axis=1)
  return {"acc": (preds == p.label_ids).mean()}

trainer = AdapterTrainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["validation"],
    compute_metrics=compute_accuracy,
)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %% [markdown]
# Start the training 🚀

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 3219
#   Num Epochs = 30
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 6060
#     <div>
#
#       <progress value='6060' max='6060' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6060/6060 1:04:57, Epoch 30/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>200</td>
#       <td>0.492000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.431100</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.403800</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.400600</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.377300</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.396200</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.404000</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.394400</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.368700</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.368900</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.348400</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.322300</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.338600</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.314000</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.337200</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.302000</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.310000</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.293200</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.297200</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.271600</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.283400</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.282900</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.273300</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.272000</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.260100</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.262400</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.264500</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.260400</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.262600</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.253800</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ./training_output/checkpoint-500
# Configuration saved in ./training_output/checkpoint-500/sciie/adapter_config.json
# Module weights saved in ./training_output/checkpoint-500/sciie/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-500/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-500/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-500/sciie/pytorch_model_head.bin
# Saving model checkpoint to ./training_output/checkpoint-1000
# Configuration saved in ./training_output/checkpoint-1000/sciie/adapter_config.json
# Module weights saved in ./training_output/checkpoint-1000/sciie/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-1000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-1000/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-1000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-1000/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-1000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-1000/sciie/pytorch_model_head.bin
# Saving model checkpoint to ./training_output/checkpoint-1500
# Configuration saved in ./training_output/checkpoint-1500/sciie/adapter_config.json
# Module weights saved in ./training_output/checkpoint-1500/sciie/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-1500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-1500/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-1500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-1500/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-1500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-1500/sciie/pytorch_model_head.bin
# Saving model checkpoint to ./training_output/checkpoint-2000
# Configuration saved in ./training_output/checkpoint-2000/sciie/adapter_config.json
# Module weights saved in ./training_output/checkpoint-2000/sciie/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-2000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-2000/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-2000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-2000/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-2000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-2000/sciie/pytorch_model_head.bin
# Saving model checkpoint to ./training_output/checkpoint-2500
# Configuration saved in ./training_output/checkpoint-2500/sciie/adapter_config.json
# Module weights saved in ./training_output/checkpoint-2500/sciie/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-2500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-2500/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-2500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-2500/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-2500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-2500/sciie/pytorch_model_head.bin
# Saving model checkpoint to ./training_output/checkpoint-3000
# Configuration saved in ./training_output/checkpoint-3000/sciie/adapter_config.json
# Module weights saved in ./training_output/checkpoint-3000/sciie/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-3000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-3000/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-3000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-3000/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-3000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-3000/sciie/pytorch_model_head.bin
# Saving model checkpoint to ./training_output/checkpoint-3500
# Configuration saved in ./training_output/checkpoint-3500/sciie/adapter_config.json
# Module weights saved in ./training_output/checkpoint-3500/sciie/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-3500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-3500/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-3500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-3500/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-3500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-3500/sciie/pytorch_model_head.bin
# Saving model checkpoint to ./training_output/checkpoint-4000
# Configuration saved in ./training_output/checkpoint-4000/sciie/adapter_config.json
# Module weights saved in ./training_output/checkpoint-4000/sciie/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-4000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-4000/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-4000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-4000/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-4000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-4000/sciie/pytorch_model_head.bin
# Saving model checkpoint to ./training_output/checkpoint-4500
# Configuration saved in ./training_output/checkpoint-4500/sciie/adapter_config.json
# Module weights saved in ./training_output/checkpoint-4500/sciie/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-4500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-4500/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-4500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-4500/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-4500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-4500/sciie/pytorch_model_head.bin
# Saving model checkpoint to ./training_output/checkpoint-5000
# Configuration saved in ./training_output/checkpoint-5000/sciie/adapter_config.json
# Module weights saved in ./training_output/checkpoint-5000/sciie/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-5000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-5000/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-5000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-5000/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-5000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-5000/sciie/pytorch_model_head.bin
# Saving model checkpoint to ./training_output/checkpoint-5500
# Configuration saved in ./training_output/checkpoint-5500/sciie/adapter_config.json
# Module weights saved in ./training_output/checkpoint-5500/sciie/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-5500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-5500/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-5500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-5500/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-5500/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-5500/sciie/pytorch_model_head.bin
# Saving model checkpoint to ./training_output/checkpoint-6000
# Configuration saved in ./training_output/checkpoint-6000/sciie/adapter_config.json
# Module weights saved in ./training_output/checkpoint-6000/sciie/pytorch_adapter.bin
# Configuration saved in ./training_output/checkpoint-6000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-6000/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-6000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-6000/sciie/pytorch_model_head.bin
# Configuration saved in ./training_output/checkpoint-6000/sciie/head_config.json
# Module weights saved in ./training_output/checkpoint-6000/sciie/pytorch_model_head.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=6060, training_loss=0.32730629200195716, metrics={'train_runtime': 3898.0, 'train_samples_per_second': 24.774, 'train_steps_per_second': 1.555, 'total_flos': 2.58503554994688e+16, 'train_loss': 0.32730629200195716, 'epoch': 30.0})

# %% [markdown]
# Looks good! Let's evaluate our adapter on the validation split of the dataset to see how well it learned:

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 455
#   Batch size = 16
#     <div>
#
#       <progress value='29' max='29' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [29/29 00:08]
#     </div>
# {'epoch': 30.0,
#  'eval_acc': 0.8725274725274725,
#  'eval_loss': 0.40560296177864075,
#  'eval_runtime': 9.0297,
#  'eval_samples_per_second': 50.389,
#  'eval_steps_per_second': 3.212}

# %% [markdown]
# We can put our trained model into a `transformers` pipeline to be able to make new predictions conveniently:

# %%
from transformers import TextClassificationPipeline

classifier = TextClassificationPipeline(model=model, tokenizer=tokenizer, device=training_args.device.index)

classifier("This is awesome!")
# Out:
# [{'label': 'LABEL_3', 'score': 0.7224643230438232}]

# %% [markdown]
# At last, we can also extract the adapter from our model and separately save it for later reuse. Note the size difference compared to a full model!

# %%
model.save_adapter("./final_adapter", "sciie")

# !ls -lh final_adapter
# Out:
# Configuration saved in ./final_adapter/adapter_config.json
# Module weights saved in ./final_adapter/pytorch_adapter.bin
# Configuration saved in ./final_adapter/head_config.json
# Module weights saved in ./final_adapter/pytorch_model_head.bin
# total 5.8M
# -rw-r--r-- 1 root root  571 Dec 14 01:09 adapter_config.json
# -rw-r--r-- 1 root root  477 Dec 14 01:09 head_config.json
# -rw-r--r-- 1 root root 3.5M Dec 14 01:09 pytorch_adapter.bin
# -rw-r--r-- 1 root root 2.3M Dec 14 01:09 pytorch_model_head.bin

# %% [markdown]
# **Share your work!**
#
# The next step after training is to share our adapter with the world via _AdapterHub_. [Read our guide](https://docs.adapterhub.ml/contributing.html) on how to prepare the adapter module we just saved and contribute it to the Hub!
#
# ➡️ Also continue with [the next Colab notebook](https://colab.research.google.com/github/Adapter-Hub/adapter-transformers/blob/master/notebooks/02_Adapter_Inference.ipynb) to learn how to use adapters from the Hub.

# %%
from google.colab import files
# !zip -r /content/file.zip /content
files.download("/content/file.zip")
# Out:
# updating: content/ (stored 0%)
# updating: content/.config/ (stored 0%)
# updating: content/.config/.last_opt_in_prompt.yaml (stored 0%)
# updating: content/.config/logs/ (stored 0%)
# updating: content/.config/logs/2021.12.03/ (stored 0%)
# updating: content/.config/logs/2021.12.03/14.32.50.522723.log (deflated 53%)
# updating: content/.config/logs/2021.12.03/14.33.16.964195.log (deflated 54%)
# updating: content/.config/logs/2021.12.03/14.33.37.701606.log (deflated 53%)
# updating: content/.config/logs/2021.12.03/14.33.36.903459.log (deflated 54%)
# updating: content/.config/logs/2021.12.03/14.33.09.955489.log (deflated 86%)
# updating: content/.config/logs/2021.12.03/14.32.30.027140.log (deflated 91%)
# updating: content/.config/.last_update_check.json (deflated 24%)
# updating: content/.config/gce (stored 0%)
# updating: content/.config/configurations/ (stored 0%)
# updating: content/.config/configurations/config_default (deflated 15%)
# updating: content/.config/active_config (stored 0%)
# updating: content/.config/config_sentinel (stored 0%)
# updating: content/.config/.last_survey_prompt.yaml (stored 0%)
# updating: content/training_output/ (stored 0%)
# updating: content/training_output/checkpoint-5000/ (stored 0%)
# updating: content/training_output/checkpoint-5000/optimizer.pt (deflated 8%)
# updating: content/training_output/checkpoint-5000/rng_state.pth (deflated 27%)
# updating: content/training_output/checkpoint-5000/trainer_state.json (deflated 79%)
# updating: content/training_output/checkpoint-5000/scheduler.pt (deflated 49%)
# updating: content/training_output/checkpoint-5000/sciie/ (stored 0%)
# updating: content/training_output/checkpoint-5000/sciie/pytorch_model_head.bin (deflated 7%)
# updating: content/training_output/checkpoint-5000/sciie/pytorch_adapter.bin (deflated 8%)
# updating: content/training_output/checkpoint-5000/sciie/adapter_config.json (deflated 56%)
# updating: content/training_output/checkpoint-5000/sciie/head_config.json (deflated 50%)
# updating: content/training_output/checkpoint-5000/training_args.bin (deflated 48%)
# updating: content/training_output/checkpoint-1000/ (stored 0%)
# updating: content/training_output/checkpoint-1000/optimizer.pt (deflated 8%)
# updating: content/training_output/checkpoint-1000/rng_state.pth (deflated 27%)
# updating: content/training_output/checkpoint-1000/trainer_state.json (deflated 65%)
# updating: content/training_output/checkpoint-1000/scheduler.pt (deflated 49%)
# updating: content/training_output/checkpoint-1000/sciie/ (stored 0%)
# updating: content/training_output/checkpoint-1000/sciie/pytorch_model_head.bin (deflated 7%)
# updating: content/training_output/checkpoint-1000/sciie/pytorch_adapter.bin (deflated 8%)
# updating: content/training_output/checkpoint-1000/sciie/adapter_config.json (deflated 56%)
# updating: content/training_output/checkpoint-1000/sciie/head_config.json (deflated 50%)
# updating: content/training_output/checkpoint-1000/training_args.bin (deflated 48%)
# updating: content/training_output/checkpoint-6000/ (stored 0%)
# updating: content/training_output/checkpoint-6000/optimizer.pt (deflated 8%)
# updating: content/training_output/checkpoint-6000/rng_state.pth (deflated 27%)
# updating: content/training_output/checkpoint-6000/trainer_state.json (deflated 80%)
# updating: content/training_output/checkpoint-6000/scheduler.pt (deflated 49%)
# updating: content/training_output/checkpoint-6000/sciie/ (stored 0%)
# updating: content/training_output/checkpoint-6000/sciie/pytorch_model_head.bin (deflated 7%)
# updating: content/training_output/checkpoint-6000/sciie/pytorch_adapter.bin (deflated 8%)
# updating: content/training_output/checkpoint-6000/sciie/adapter_config.json (deflated 56%)
# updating: content/training_output/checkpoint-6000/sciie/head_config.json (deflated 50%)
# updating: content/training_output/checkpoint-6000/training_args.bin (deflated 48%)
# updating: content/training_output/checkpoint-1500/ (stored 0%)
# updating: content/training_output/checkpoint-1500/optimizer.pt (deflated 8%)
# updating: content/training_output/checkpoint-1500/rng_state.pth (deflated 27%)
# updating: content/training_output/checkpoint-1500/trainer_state.json (deflated 69%)
# updating: content/training_output/checkpoint-1500/scheduler.pt (deflated 49%)
# updating: content/training_output/checkpoint-1500/sciie/ (stored 0%)
# updating: content/training_output/checkpoint-1500/sciie/pytorch_model_head.bin (deflated 7%)
# updating: content/training_output/checkpoint-1500/sciie/pytorch_adapter.bin (deflated 8%)
# updating: content/training_output/checkpoint-1500/sciie/adapter_config.json (deflated 56%)
# updating: content/training_output/checkpoint-1500/sciie/head_config.json (deflated 50%)
# updating: content/training_output/checkpoint-1500/training_args.bin (deflated 48%)
# updating: content/training_output/checkpoint-500/ (stored 0%)
# updating: content/training_output/checkpoint-500/optimizer.pt (deflated 8%)
# updating: content/training_output/checkpoint-500/rng_state.pth (deflated 27%)
# updating: content/training_output/checkpoint-500/trainer_state.json (deflated 53%)
# updating: content/training_output/checkpoint-500/scheduler.pt (deflated 49%)
# updating: content/training_output/checkpoint-500/sciie/ (stored 0%)
# updating: content/training_output/checkpoint-500/sciie/pytorch_model_head.bin (deflated 7%)
# updating: content/training_output/checkpoint-500/sciie/pytorch_adapter.bin (deflated 8%)
# updating: content/training_output/checkpoint-500/sciie/adapter_config.json (deflated 56%)
# updating: content/training_output/checkpoint-500/sciie/head_config.json (deflated 50%)
# updating: content/training_output/checkpoint-500/training_args.bin (deflated 48%)
# updating: content/training_output/checkpoint-2000/ (stored 0%)
# updating: content/training_output/checkpoint-2000/optimizer.pt (deflated 8%)
# updating: content/training_output/checkpoint-2000/rng_state.pth (deflated 27%)
# updating: content/training_output/checkpoint-2000/trainer_state.json (deflated 73%)
# updating: content/training_output/checkpoint-2000/scheduler.pt (deflated 49%)
# updating: content/training_output/checkpoint-2000/sciie/ (stored 0%)
# updating: content/training_output/checkpoint-2000/sciie/pytorch_model_head.bin (deflated 7%)
# updating: content/training_output/checkpoint-2000/sciie/pytorch_adapter.bin (deflated 8%)
# updating: content/training_output/checkpoint-2000/sciie/adapter_config.json (deflated 56%)
# updating: content/training_output/checkpoint-2000/sciie/head_config.json (deflated 50%)
# updating: content/training_output/checkpoint-2000/training_args.bin (deflated 48%)
# updating: content/training_output/checkpoint-4500/ (stored 0%)
# updating: content/training_output/checkpoint-4500/optimizer.pt (deflated 8%)
# updating: content/training_output/checkpoint-4500/rng_state.pth (deflated 27%)
# updating: content/training_output/checkpoint-4500/trainer_state.json (deflated 79%)
# updating: content/training_output/checkpoint-4500/scheduler.pt (deflated 49%)
# updating: content/training_output/checkpoint-4500/sciie/ (stored 0%)
# updating: content/training_output/checkpoint-4500/sciie/pytorch_model_head.bin (deflated 7%)
# updating: content/training_output/checkpoint-4500/sciie/pytorch_adapter.bin (deflated 8%)
# updating: content/training_output/checkpoint-4500/sciie/adapter_config.json (deflated 56%)
# updating: content/training_output/checkpoint-4500/sciie/head_config.json (deflated 50%)
# updating: content/training_output/checkpoint-4500/training_args.bin (deflated 48%)
# updating: content/training_output/checkpoint-5500/ (stored 0%)
# updating: content/training_output/checkpoint-5500/optimizer.pt (deflated 8%)
# updating: content/training_output/checkpoint-5500/rng_state.pth (deflated 27%)
# updating: content/training_output/checkpoint-5500/trainer_state.json (deflated 80%)
# updating: content/training_output/checkpoint-5500/scheduler.pt (deflated 49%)
# updating: content/training_output/checkpoint-5500/sciie/ (stored 0%)
# updating: content/training_output/checkpoint-5500/sciie/pytorch_model_head.bin (deflated 7%)
# updating: content/training_output/checkpoint-5500/sciie/pytorch_adapter.bin (deflated 8%)
# updating: content/training_output/checkpoint-5500/sciie/adapter_config.json (deflated 56%)
# updating: content/training_output/checkpoint-5500/sciie/head_config.json (deflated 50%)
# updating: content/training_output/checkpoint-5500/training_args.bin (deflated 48%)
# updating: content/training_output/checkpoint-4000/ (stored 0%)
# updating: content/training_output/checkpoint-4000/optimizer.pt (deflated 8%)
# updating: content/training_output/checkpoint-4000/rng_state.pth (deflated 27%)
# updating: content/training_output/checkpoint-4000/trainer_state.json (deflated 78%)
# updating: content/training_output/checkpoint-4000/scheduler.pt (deflated 49%)
# updating: content/training_output/checkpoint-4000/sciie/ (stored 0%)
# updating: content/training_output/checkpoint-4000/sciie/pytorch_model_head.bin (deflated 7%)
# updating: content/training_output/checkpoint-4000/sciie/pytorch_adapter.bin (deflated 8%)
# updating: content/training_output/checkpoint-4000/sciie/adapter_config.json (deflated 56%)
# updating: content/training_output/checkpoint-4000/sciie/head_config.json (deflated 50%)
# updating: content/training_output/checkpoint-4000/training_args.bin (deflated 48%)
# updating: content/training_output/checkpoint-2500/ (stored 0%)
# updating: content/training_output/checkpoint-2500/optimizer.pt (deflated 8%)
# updating: content/training_output/checkpoint-2500/rng_state.pth (deflated 27%)
# updating: content/training_output/checkpoint-2500/trainer_state.json (deflated 74%)
# updating: content/training_output/checkpoint-2500/scheduler.pt (deflated 49%)
# updating: content/training_output/checkpoint-2500/sciie/ (stored 0%)
# updating: content/training_output/checkpoint-2500/sciie/pytorch_model_head.bin (deflated 7%)
# updating: content/training_output/checkpoint-2500/sciie/pytorch_adapter.bin (deflated 8%)
# updating: content/training_output/checkpoint-2500/sciie/adapter_config.json (deflated 56%)
# updating: content/training_output/checkpoint-2500/sciie/head_config.json (deflated 50%)
# updating: content/training_output/checkpoint-2500/training_args.bin (deflated 48%)
# updating: content/training_output/runs/ (stored 0%)
# updating: content/training_output/runs/Dec13_23-22-09_ba5dc722d81f/ (stored 0%)
# updating: content/training_output/runs/Dec13_23-22-09_ba5dc722d81f/events.out.tfevents.1639437733.ba5dc722d81f.109.3 (deflated 62%)
# updating: content/training_output/runs/Dec13_23-22-09_ba5dc722d81f/events.out.tfevents.1639442955.ba5dc722d81f.109.5 (deflated 27%)
# updating: content/training_output/runs/Dec13_23-22-09_ba5dc722d81f/1639437733.9650137/ (stored 0%)
# updating: content/training_output/runs/Dec13_23-22-09_ba5dc722d81f/1639437733.9650137/events.out.tfevents.1639437733.ba5dc722d81f.109.4 (deflated 62%)
# updating: content/training_output/runs/Dec13_23-03-58_ba5dc722d81f/ (stored 0%)
# updating: content/training_output/runs/Dec13_23-03-58_ba5dc722d81f/events.out.tfevents.1639436644.ba5dc722d81f.109.0 (deflated 59%)
# updating: content/training_output/runs/Dec13_23-03-58_ba5dc722d81f/events.out.tfevents.1639437705.ba5dc722d81f.109.2 (deflated 28%)
# updating: content/training_output/runs/Dec13_23-03-58_ba5dc722d81f/1639436644.828434/ (stored 0%)
# updating: content/training_output/runs/Dec13_23-03-58_ba5dc722d81f/1639436644.828434/events.out.tfevents.1639436644.ba5dc722d81f.109.1 (deflated 62%)
# updating: content/training_output/checkpoint-3500/ (stored 0%)
# updating: content/training_output/checkpoint-3500/optimizer.pt (deflated 8%)
# updating: content/training_output/checkpoint-3500/rng_state.pth (deflated 27%)
# updating: content/training_output/checkpoint-3500/trainer_state.json (deflated 77%)
# updating: content/training_output/checkpoint-3500/scheduler.pt (deflated 49%)
# updating: content/training_output/checkpoint-3500/sciie/ (stored 0%)
# updating: content/training_output/checkpoint-3500/sciie/pytorch_model_head.bin (deflated 7%)
# updating: content/training_output/checkpoint-3500/sciie/pytorch_adapter.bin (deflated 8%)
# updating: content/training_output/checkpoint-3500/sciie/adapter_config.json (deflated 56%)
# updating: content/training_output/checkpoint-3500/sciie/head_config.json (deflated 50%)
# updating: content/training_output/checkpoint-3500/training_args.bin (deflated 48%)
# updating: content/training_output/checkpoint-3000/ (stored 0%)
# updating: content/training_output/checkpoint-3000/optimizer.pt (deflated 8%)
# updating: content/training_output/checkpoint-3000/rng_state.pth (deflated 27%)
# updating: content/training_output/checkpoint-3000/trainer_state.json (deflated 76%)
# updating: content/training_output/checkpoint-3000/scheduler.pt (deflated 49%)
# updating: content/training_output/checkpoint-3000/sciie/ (stored 0%)
# updating: content/training_output/checkpoint-3000/sciie/pytorch_model_head.bin (deflated 7%)
# updating: content/training_output/checkpoint-3000/sciie/pytorch_adapter.bin (deflated 8%)
# updating: content/training_output/checkpoint-3000/sciie/adapter_config.json (deflated 56%)
# updating: content/training_output/checkpoint-3000/sciie/head_config.json (deflated 50%)
# updating: content/training_output/checkpoint-3000/training_args.bin (deflated 48%)
# updating: content/sample_data/ (stored 0%)
# updating: content/sample_data/anscombe.json (deflated 83%)
# updating: content/sample_data/README.md (deflated 42%)
# updating: content/sample_data/mnist_train_small.csv (deflated 88%)
# updating: content/sample_data/california_housing_test.csv (deflated 76%)
# updating: content/sample_data/california_housing_train.csv (deflated 79%)
# updating: content/sample_data/mnist_test.csv (deflated 88%)
#   adding: content/final_adapter/ (stored 0%)
#   adding: content/final_adapter/pytorch_model_head.bin (deflated 7%)
#   adding: content/final_adapter/pytorch_adapter.bin (deflated 8%)
#   adding: content/final_adapter/adapter_config.json (deflated 58%)
#   adding: content/final_adapter/head_config.json (deflated 50%)
