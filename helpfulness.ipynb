# %% [markdown]
# # 1️⃣ Training an Adapter for a Transformer model
#
# In this notebook, we train an adapter for a **RoBERTa** ([Liu et al., 2019](https://arxiv.org/pdf/1907.11692.pdf)) model for sequence classification on a **sentiment analysis** task using [adapter-transformers](https://github.com/Adapter-Hub/adapter-transformers), the _AdapterHub_ adaptation of HuggingFace's _transformers_ library.
#
# If you're unfamiliar with the theoretical parts of adapters or the AdapterHub framework, check out our [introductory blog post](https://adapterhub.ml/blog/2020/11/adapting-transformers-with-adapterhub/) first.
#
# We train a **Task Adapter** for a pre-trained model here. Most of the code is identical to a full finetuning setup using HuggingFace's transformers. For comparison, have a look at the [same guide using full finetuning](https://colab.research.google.com/drive/1brXJg5Mokm8h3shxqPRnoIsRwHQoncus?usp=sharing).
#
# For training, we use the [movie review dataset by Pang and Lee (2005)](http://www.cs.cornell.edu/people/pabo/movie-review-data/). It contains movie reviews  from Rotten Tomatoes which are either classified as positive or negative. We download the dataset via HuggingFace's [datasets](https://github.com/huggingface/datasets) library.

# %% [markdown]
# ## Installation
#
# First, let's install the required libraries:

# %%
# !pip install -U adapter-transformers
# !pip install datasets
# Out:
# Requirement already satisfied: adapter-transformers in c:\users\junfe\anaconda3\lib\site-packages (2.2.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\junfe\anaconda3\lib\site-packages (from adapter-transformers) (2021.8.3)
# Requirement already satisfied: filelock in c:\users\junfe\anaconda3\lib\site-packages (from adapter-transformers) (3.3.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\junfe\anaconda3\lib\site-packages (from adapter-transformers) (1.20.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\junfe\anaconda3\lib\site-packages (from adapter-transformers) (4.62.3)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in c:\users\junfe\anaconda3\lib\site-packages (from adapter-transformers) (0.10.3)
# Requirement already satisfied: requests in c:\users\junfe\anaconda3\lib\site-packages (from adapter-transformers) (2.26.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\junfe\anaconda3\lib\site-packages (from adapter-transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\junfe\anaconda3\lib\site-packages (from adapter-transformers) (21.3)
# Requirement already satisfied: sacremoses in c:\users\junfe\anaconda3\lib\site-packages (from adapter-transformers) (0.0.46)
# Requirement already satisfied: huggingface-hub>=0.0.17 in c:\users\junfe\anaconda3\lib\site-packages (from adapter-transformers) (0.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\junfe\anaconda3\lib\site-packages (from huggingface-hub>=0.0.17->adapter-transformers) (3.10.0.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\junfe\anaconda3\lib\site-packages (from packaging>=20.0->adapter-transformers) (3.0.4)
# Requirement already satisfied: colorama in c:\users\junfe\anaconda3\lib\site-packages (from tqdm>=4.27->adapter-transformers) (0.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\junfe\anaconda3\lib\site-packages (from requests->adapter-transformers) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\junfe\anaconda3\lib\site-packages (from requests->adapter-transformers) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\junfe\anaconda3\lib\site-packages (from requests->adapter-transformers) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\junfe\anaconda3\lib\site-packages (from requests->adapter-transformers) (2.0.4)
# Requirement already satisfied: click in c:\users\junfe\anaconda3\lib\site-packages (from sacremoses->adapter-transformers) (7.1.2)
# Requirement already satisfied: six in c:\users\junfe\anaconda3\lib\site-packages (from sacremoses->adapter-transformers) (1.16.0)
# Requirement already satisfied: joblib in c:\users\junfe\anaconda3\lib\site-packages (from sacremoses->adapter-transformers) (1.1.0)
# Requirement already satisfied: datasets in c:\users\junfe\anaconda3\lib\site-packages (1.16.1)
# Requirement already satisfied: dill in c:\users\junfe\anaconda3\lib\site-packages (from datasets) (0.3.4)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in c:\users\junfe\anaconda3\lib\site-packages (from datasets) (2021.10.1)
# Requirement already satisfied: packaging in c:\users\junfe\anaconda3\lib\site-packages (from datasets) (21.3)
# Requirement already satisfied: pandas in c:\users\junfe\anaconda3\lib\site-packages (from datasets) (1.3.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\junfe\anaconda3\lib\site-packages (from datasets) (1.20.3)
# Requirement already satisfied: xxhash in c:\users\junfe\anaconda3\lib\site-packages (from datasets) (2.0.2)
# Requirement already satisfied: aiohttp in c:\users\junfe\anaconda3\lib\site-packages (from datasets) (3.8.1)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in c:\users\junfe\anaconda3\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\junfe\anaconda3\lib\site-packages (from datasets) (4.62.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\junfe\anaconda3\lib\site-packages (from datasets) (2.26.0)
# Requirement already satisfied: multiprocess in c:\users\junfe\anaconda3\lib\site-packages (from datasets) (0.70.12.2)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.1.0 in c:\users\junfe\anaconda3\lib\site-packages (from datasets) (0.2.1)
# Requirement already satisfied: filelock in c:\users\junfe\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\junfe\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (3.10.0.2)
# Requirement already satisfied: pyyaml in c:\users\junfe\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets) (6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\junfe\anaconda3\lib\site-packages (from packaging->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\junfe\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\junfe\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\junfe\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\junfe\anaconda3\lib\site-packages (from requests>=2.19.0->datasets) (2.0.4)
# Requirement already satisfied: colorama in c:\users\junfe\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\junfe\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\junfe\anaconda3\lib\site-packages (from aiohttp->datasets) (1.5.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\junfe\anaconda3\lib\site-packages (from aiohttp->datasets) (4.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\junfe\anaconda3\lib\site-packages (from aiohttp->datasets) (21.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\junfe\anaconda3\lib\site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\junfe\anaconda3\lib\site-packages (from aiohttp->datasets) (5.1.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\junfe\anaconda3\lib\site-packages (from pandas->datasets) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\junfe\anaconda3\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\junfe\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.16.0)

# %% [markdown]
# ## Dataset Preprocessing
#
# Before we start to train our adapter, we first prepare the training data. Our training dataset can be loaded via HuggingFace `datasets` using one line of code:

# %%
from datasets import load_dataset, DatasetDict

dataset = load_dataset("vannacute/AmazonReviewHelpfulness")
dataset.num_rows
# Out:
# Using custom data configuration vannacute___AmazonReviewHelpfulness-303f37a529acb78b
# Reusing dataset json (C:\Users\Junfe\.cache\huggingface\datasets\json\vannacute___AmazonReviewHelpfulness-303f37a529acb78b\0.0.0\c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426)
#   0%|          | 0/3 [00:00<?, ?it/s]
# {'train': 115251, 'test': 25000, 'validation': 5000}

# %% [markdown]
# Every dataset sample has an input text and a binary label:

# %%
# dataset['train']['label']
l = dataset['validation'].map(lambda x : torch.tensor([False]) if x=='unhelpful' else x)
# Out:
# Loading cached processed dataset at C:\Users\Junfe\.cache\huggingface\datasets\json\vannacute___AmazonReviewHelpfulness-303f37a529acb78b\0.0.0\c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426\cache-358380962e9a411c.arrow

# %%
def maplabel(example):
  if example['label'] == "helpful":
    example['label'] = True
  else:
    example['label'] = False
  return example

dataset['train'] = dataset['train'] .map(maplabel)
# Out:
# Loading cached processed dataset at C:\Users\Junfe\.cache\huggingface\datasets\json\vannacute___AmazonReviewHelpfulness-303f37a529acb78b\0.0.0\c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426\cache-cafbfb4aaccebbe1.arrow

# %%
dataset['validation'] = dataset['validation'] .map(maplabel)
dataset['test'] = dataset['test'] .map(maplabel)
# Out:
# Loading cached processed dataset at C:\Users\Junfe\.cache\huggingface\datasets\json\vannacute___AmazonReviewHelpfulness-303f37a529acb78b\0.0.0\c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426\cache-c9cca26846ef6e7c.arrow
# Loading cached processed dataset at C:\Users\Junfe\.cache\huggingface\datasets\json\vannacute___AmazonReviewHelpfulness-303f37a529acb78b\0.0.0\c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426\cache-de634f1ae6dbf563.arrow

# %%
from datasets import ClassLabel, Value
for name in ['train','validation','test']:
  new_features = dataset[name].features.copy()
  new_features["label"] = ClassLabel(names=['neg', 'pos'])
  dataset[name] = dataset[name].cast(new_features)
  dataset[name].features
# Out:
# Loading cached processed dataset at C:\Users\Junfe\.cache\huggingface\datasets\json\vannacute___AmazonReviewHelpfulness-303f37a529acb78b\0.0.0\c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426\cache-9aa234147fb8c46e.arrow
# Loading cached processed dataset at C:\Users\Junfe\.cache\huggingface\datasets\json\vannacute___AmazonReviewHelpfulness-303f37a529acb78b\0.0.0\c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426\cache-cd2b31a31ac7f2b3.arrow
# Loading cached processed dataset at C:\Users\Junfe\.cache\huggingface\datasets\json\vannacute___AmazonReviewHelpfulness-303f37a529acb78b\0.0.0\c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426\cache-3c5f6ab84b09a825.arrow

# %% [markdown]
# Now, we need to encode all dataset samples to valid inputs for our Transformer model. Since we want to train on `roberta-base`, we load the corresponding `RobertaTokenizer`. Using `dataset.map()`, we can pass the full dataset through the tokenizer in batches:

# %%
import numpy as np
nLabels = len(np.unique(dataset['train']['label']))
nLabels
# Out:
# 2

# %%
from transformers import RobertaTokenizer

tokenizer = RobertaTokenizer.from_pretrained("roberta-base")

def encode_batch(batch):
  """Encodes a batch of input data using the model tokenizer."""
  return tokenizer(batch["text"], max_length=512, truncation=True, padding="max_length")

# Encode the input data
dataset = dataset.map(encode_batch, batched=True)
# The transformers model expects the target class column to be named "labels"
dataset.rename_column_("label", "labels")
# Transform to pytorch tensors and only output the required columns
dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "labels"])
# Out:
# Loading cached processed dataset at C:\Users\Junfe\.cache\huggingface\datasets\json\vannacute___AmazonReviewHelpfulness-303f37a529acb78b\0.0.0\c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426\cache-fd26f8d8458f9cc3.arrow
# Loading cached processed dataset at C:\Users\Junfe\.cache\huggingface\datasets\json\vannacute___AmazonReviewHelpfulness-303f37a529acb78b\0.0.0\c2d554c3377ea79c7664b93dc65d0803b45e3279000f993c7bfd18937fd7f426\cache-63cd9525b0016482.arrow
#   0%|          | 0/5 [00:00<?, ?ba/s]
# C:\Users\Junfe\AppData\Local\Temp/ipykernel_40320/1657904570.py:12: FutureWarning: rename_column_ is deprecated and will be removed in the next major version of datasets. Use DatasetDict.rename_column instead.
#   dataset.rename_column_("label", "labels")

# %% [markdown]
# Now we're ready to train our model...

# %% [markdown]
# ## Training
#
# We use a pre-trained RoBERTa model from HuggingFace. We use `RobertaModelWithHeads`, a class unique to `adapter-transformers`, which allows us to add and configure prediction heads in a flexibler way.

# %%
# dataset['train']['labels']

# %%
from transformers import RobertaConfig, RobertaModelWithHeads

config = RobertaConfig.from_pretrained(
    "roberta-base",
    num_labels=2,
)
model = RobertaModelWithHeads.from_pretrained(
    "roberta-base",
    config=config,
)
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModelWithHeads: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.bias', 'lm_head.dense.bias', 'lm_head.layer_norm.bias']
# - This IS expected if you are initializing RobertaModelWithHeads from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModelWithHeads from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModelWithHeads were not initialized from the model checkpoint at roberta-base and are newly initialized: ['roberta.embeddings.position_ids']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# **Here comes the important part!**
#
# We add a new adapter to our model by calling `add_adapter()`. We pass a name (`"rotten_tomatoes"`) and [the type of adapter](https://docs.adapterhub.ml/adapters.html#adapter-types) (task adapter). Next, we add a binary classification head. It's convenient to give the prediction head the same name as the adapter. This allows us to activate both together in the next step. The `train_adapter()` method does two things:
#
# 1. It freezes all weights of the pre-trained model so only the adapter weights are updated during training.
# 2. It activates the adapter and the prediction head such that both are used in every forward pass.

# %%
adaptername = 'Helpfulness'

# Add a new adapter
model.add_adapter(adaptername)
# Add a matching classification head
model.add_classification_head(
    adaptername,
    num_labels=2
    # id2label={ 0: "👎", 1: "👍"}
  )
# Activate the adapter
model.train_adapter(adaptername)

# %% [markdown]
# For training, we make use of the `Trainer` class built-in into `transformers`. We configure the training process using a `TrainingArguments` object and define a method that will calculate the evaluation accuracy in the end. We pass both, together with the training and validation split of our dataset, to the trainer instance.
#
# **Note the differences in hyperparameters compared to full finetuning.** Adapter training usually required a few more training epochs than full finetuning.

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['attention_mask', 'id', 'input_ids', 'labels', 'text'],
#         num_rows: 115251
#     })
#     test: Dataset({
#         features: ['attention_mask', 'id', 'input_ids', 'labels', 'text'],
#         num_rows: 25000
#     })
#     validation: Dataset({
#         features: ['attention_mask', 'id', 'input_ids', 'labels', 'text'],
#         num_rows: 5000
#     })
# })

# %%
import numpy as np
from transformers import TrainingArguments, AdapterTrainer, EvalPrediction

training_args = TrainingArguments(
    learning_rate=1e-4,
    num_train_epochs=6,
    per_device_train_batch_size=12,
    per_device_eval_batch_size=12,
    logging_steps=200,
    output_dir="./training_output",
    overwrite_output_dir=True,
    # The next line is important to ensure the dataset labels are properly passed to the model
    remove_unused_columns=False,
)

def compute_accuracy(p: EvalPrediction):
  preds = np.argmax(p.predictions, axis=1)
  return {"acc": (preds == p.label_ids).mean()}

trainer = AdapterTrainer(
    model=model,
    args=training_args,
    train_dataset=dataset["train"],
    eval_dataset=dataset["validation"],
    compute_metrics=compute_accuracy,
)

# %% [markdown]
# Start the training 🚀

# %%
# gpu_info = !nvidia-smi
# gpu_info = '\n'.join(gpu_info)
# if gpu_info.find('failed') >= 0:
#   print('Not connected to a GPU')
# else:
#   print(gpu_info)

# %%
trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 115251
#   Num Epochs = 6
#   Instantaneous batch size per device = 12
#   Total train batch size (w. parallel, distributed & accumulation) = 12
#   Gradient Accumulation steps = 1
#   Total optimization steps = 57630
#     <div>
#
#       <progress value='57630' max='57630' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [57630/57630 3:15:26, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>200</td>
#       <td>0.440500</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.353100</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.356100</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.371100</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.357200</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.332900</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.338200</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.356600</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.341200</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.325100</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.353700</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.349800</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.327300</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.357200</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.323600</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.323900</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.323200</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.366600</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.322500</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.326700</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.319600</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.328800</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.314800</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.346300</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.315600</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.321100</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.322700</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.323200</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.295500</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.338300</td>
#     </tr>
#     <tr>
#       <td>6200</td>
#       <td>0.334500</td>
#     </tr>
#     <tr>
#       <td>6400</td>
#       <td>0.326000</td>
#     </tr>
#     <tr>
#       <td>6600</td>
#       <td>0.307700</td>
#     </tr>
#     <tr>
#       <td>6800</td>
#       <td>0.302200</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.319700</td>
#     </tr>
#     <tr>
#       <td>7200</td>
#       <td>0.332000</td>
#     </tr>
#     <tr>
#       <td>7400</td>
#       <td>0.326500</td>
#     </tr>
#     <tr>
#       <td>7600</td>
#       <td>0.312000</td>
#     </tr>
#     <tr>
#       <td>7800</td>
#       <td>0.319300</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.298300</td>
#     </tr>
#     <tr>
#       <td>8200</td>
#       <td>0.318300</td>
#     </tr>
#     <tr>
#       <td>8400</td>
#       <td>0.341600</td>
#     </tr>
#     <tr>
#       <td>8600</td>
#       <td>0.311100</td>
#     </tr>
#     <tr>
#       <td>8800</td>
#       <td>0.306200</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.316400</td>
#     </tr>
#     <tr>
#       <td>9200</td>
#       <td>0.330900</td>
#     </tr>
#     <tr>
#       <td>9400</td>
#       <td>0.288600</td>
#     </tr>
#     <tr>
#       <td>9600</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>9800</td>
#       <td>0.302100</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.289900</td>
#     </tr>
#     <tr>
#       <td>10200</td>
#       <td>0.320500</td>
#     </tr>
#     <tr>
#       <td>10400</td>
#       <td>0.308200</td>
#     </tr>
#     <tr>
#       <td>10600</td>
#       <td>0.337000</td>
#     </tr>
#     <tr>
#       <td>10800</td>
#       <td>0.296400</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.307700</td>
#     </tr>
#     <tr>
#       <td>11200</td>
#       <td>0.290600</td>
#     </tr>
#     <tr>
#       <td>11400</td>
#       <td>0.301800</td>
#     </tr>
#     <tr>
#       <td>11600</td>
#       <td>0.310700</td>
#     </tr>
#     <tr>
#       <td>11800</td>
#       <td>0.321500</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.306000</td>
#     </tr>
#     <tr>
#       <td>12200</td>
#       <td>0.327800</td>
#     </tr>
#     <tr>
#       <td>12400</td>
#       <td>0.305300</td>
#     </tr>
#     <tr>
#       <td>12600</td>
#       <td>0.326300</td>
#     </tr>
#     <tr>
#       <td>12800</td>
#       <td>0.330800</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.286700</td>
#     </tr>
#     <tr>
#       <td>13200</td>
#       <td>0.321100</td>
#     </tr>
#     <tr>
#       <td>13400</td>
#       <td>0.320800</td>
#     </tr>
#     <tr>
#       <td>13600</td>
#       <td>0.308800</td>
#     </tr>
#     <tr>
#       <td>13800</td>
#       <td>0.301000</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.313200</td>
#     </tr>
#     <tr>
#       <td>14200</td>
#       <td>0.309700</td>
#     </tr>
#     <tr>
#       <td>14400</td>
#       <td>0.297700</td>
#     </tr>
#     <tr>
#       <td>14600</td>
#       <td>0.320400</td>
#     </tr>
#     <tr>
#       <td>14800</td>
#       <td>0.297500</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.305600</td>
#     </tr>
#     <tr>
#       <td>15200</td>
#       <td>0.294800</td>
#     </tr>
#     <tr>
#       <td>15400</td>
#       <td>0.302200</td>
#     </tr>
#     <tr>
#       <td>15600</td>
#       <td>0.287300</td>
#     </tr>
#     <tr>
#       <td>15800</td>
#       <td>0.299800</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.317200</td>
#     </tr>
#     <tr>
#       <td>16200</td>
#       <td>0.299100</td>
#     </tr>
#     <tr>
#       <td>16400</td>
#       <td>0.311100</td>
#     </tr>
#     <tr>
#       <td>16600</td>
#       <td>0.298100</td>
#     </tr>
#     <tr>
#       <td>16800</td>
#       <td>0.307500</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.307400</td>
#     </tr>
#     <tr>
#       <td>17200</td>
#       <td>0.287500</td>
#     </tr>
#     <tr>
#       <td>17400</td>
#       <td>0.309300</td>
#     </tr>
#     <tr>
#       <td>17600</td>
#       <td>0.316800</td>
#     </tr>
#     <tr>
#       <td>17800</td>
#       <td>0.314000</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.308300</td>
#     </tr>
#     <tr>
#       <td>18200</td>
#       <td>0.307200</td>
#     </tr>
#     <tr>
#       <td>18400</td>
#       <td>0.279700</td>
#     </tr>
#     <tr>
#       <td>18600</td>
#       <td>0.308300</td>
#     </tr>
#     <tr>
#       <td>18800</td>
#       <td>0.323200</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.317200</td>
#     </tr>
#     <tr>
#       <td>19200</td>
#       <td>0.299900</td>
#     </tr>
#     <tr>
#       <td>19400</td>
#       <td>0.308400</td>
#     </tr>
#     <tr>
#       <td>19600</td>
#       <td>0.300000</td>
#     </tr>
#     <tr>
#       <td>19800</td>
#       <td>0.291900</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.325100</td>
#     </tr>
#     <tr>
#       <td>20200</td>
#       <td>0.296500</td>
#     </tr>
#     <tr>
#       <td>20400</td>
#       <td>0.287200</td>
#     </tr>
#     <tr>
#       <td>20600</td>
#       <td>0.305000</td>
#     </tr>
#     <tr>
#       <td>20800</td>
#       <td>0.296300</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>0.312700</td>
#     </tr>
#     <tr>
#       <td>21200</td>
#       <td>0.295600</td>
#     </tr>
#     <tr>
#       <td>21400</td>
#       <td>0.301100</td>
#     </tr>
#     <tr>
#       <td>21600</td>
#       <td>0.306600</td>
#     </tr>
#     <tr>
#       <td>21800</td>
#       <td>0.308800</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.291400</td>
#     </tr>
#     <tr>
#       <td>22200</td>
#       <td>0.309200</td>
#     </tr>
#     <tr>
#       <td>22400</td>
#       <td>0.302900</td>
#     </tr>
#     <tr>
#       <td>22600</td>
#       <td>0.293100</td>
#     </tr>
#     <tr>
#       <td>22800</td>
#       <td>0.310200</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>0.290500</td>
#     </tr>
#     <tr>
#       <td>23200</td>
#       <td>0.298100</td>
#     </tr>
#     <tr>
#       <td>23400</td>
#       <td>0.302500</td>
#     </tr>
#     <tr>
#       <td>23600</td>
#       <td>0.308800</td>
#     </tr>
#     <tr>
#       <td>23800</td>
#       <td>0.310000</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.298500</td>
#     </tr>
#     <tr>
#       <td>24200</t
# Saving model checkpoint to ./training_output\checkpoint-500
# Configuration saved in ./training_output\checkpoint-500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-1000
# Configuration saved in ./training_output\checkpoint-1000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-1000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-1000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-1000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-1000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-1000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-1000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-1000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-1500
# Configuration saved in ./training_output\checkpoint-1500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-1500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-1500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-1500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-1500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-1500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-1500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-1500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-2000
# Configuration saved in ./training_output\checkpoint-2000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-2000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-2000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-2000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-2000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-2000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-2000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-2000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-2500
# Configuration saved in ./training_output\checkpoint-2500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-2500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-2500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-2500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-2500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-2500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-2500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-2500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-3000
# Configuration saved in ./training_output\checkpoint-3000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-3000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-3000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-3000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-3000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-3000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-3000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-3000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-3500
# Configuration saved in ./training_output\checkpoint-3500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-3500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-3500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-3500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-3500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-3500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-3500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-3500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-4000
# Configuration saved in ./training_output\checkpoint-4000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-4000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-4000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-4000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-4000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-4000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-4000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-4000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-4500
# Configuration saved in ./training_output\checkpoint-4500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-4500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-4500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-4500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-4500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-4500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-4500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-4500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-5000
# Configuration saved in ./training_output\checkpoint-5000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-5000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-5000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-5000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-5000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-5000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-5000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-5000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-5500
# Configuration saved in ./training_output\checkpoint-5500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-5500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-5500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-5500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-5500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-5500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-5500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-5500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-6000
# Configuration saved in ./training_output\checkpoint-6000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-6000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-6000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-6000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-6000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-6000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-6000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-6000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-6500
# Configuration saved in ./training_output\checkpoint-6500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-6500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-6500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-6500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-6500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-6500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-6500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-6500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-7000
# Configuration saved in ./training_output\checkpoint-7000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-7000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-7000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-7000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-7000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-7000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-7000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-7000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-7500
# Configuration saved in ./training_output\checkpoint-7500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-7500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-7500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-7500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-7500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-7500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-7500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-7500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-8000
# Configuration saved in ./training_output\checkpoint-8000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-8000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-8000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-8000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-8000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-8000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-8000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-8000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-8500
# Configuration saved in ./training_output\checkpoint-8500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-8500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-8500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-8500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-8500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-8500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-8500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-8500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-9000
# Configuration saved in ./training_output\checkpoint-9000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-9000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-9000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-9000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-9000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-9000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-9000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-9000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-9500
# Configuration saved in ./training_output\checkpoint-9500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-9500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-9500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-9500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-9500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-9500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-9500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-9500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-10000
# Configuration saved in ./training_output\checkpoint-10000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-10000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-10000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-10000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-10000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-10000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-10000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-10000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-10500
# Configuration saved in ./training_output\checkpoint-10500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-10500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-10500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-10500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-10500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-10500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-10500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-10500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-11000
# Configuration saved in ./training_output\checkpoint-11000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-11000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-11000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-11000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-11000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-11000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-11000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-11000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-11500
# Configuration saved in ./training_output\checkpoint-11500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-11500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-11500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-11500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-11500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-11500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-11500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-11500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-12000
# Configuration saved in ./training_output\checkpoint-12000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-12000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-12000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-12000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-12000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-12000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-12000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-12000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-12500
# Configuration saved in ./training_output\checkpoint-12500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-12500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-12500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-12500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-12500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-12500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-12500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-12500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-13000
# Configuration saved in ./training_output\checkpoint-13000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-13000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-13000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-13000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-13000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-13000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-13000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-13000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-13500
# Configuration saved in ./training_output\checkpoint-13500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-13500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-13500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-13500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-13500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-13500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-13500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-13500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-14000
# Configuration saved in ./training_output\checkpoint-14000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-14000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-14000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-14000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-14000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-14000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-14000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-14000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-14500
# Configuration saved in ./training_output\checkpoint-14500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-14500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-14500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-14500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-14500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-14500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-14500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-14500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-15000
# Configuration saved in ./training_output\checkpoint-15000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-15000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-15000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-15000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-15000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-15000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-15000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-15000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-15500
# Configuration saved in ./training_output\checkpoint-15500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-15500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-15500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-15500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-15500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-15500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-15500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-15500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-16000
# Configuration saved in ./training_output\checkpoint-16000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-16000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-16000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-16000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-16000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-16000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-16000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-16000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-16500
# Configuration saved in ./training_output\checkpoint-16500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-16500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-16500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-16500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-16500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-16500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-16500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-16500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-17000
# Configuration saved in ./training_output\checkpoint-17000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-17000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-17000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-17000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-17000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-17000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-17000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-17000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-17500
# Configuration saved in ./training_output\checkpoint-17500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-17500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-17500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-17500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-17500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-17500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-17500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-17500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-18000
# Configuration saved in ./training_output\checkpoint-18000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-18000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-18000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-18000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-18000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-18000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-18000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-18000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-18500
# Configuration saved in ./training_output\checkpoint-18500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-18500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-18500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-18500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-18500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-18500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-18500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-18500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-19000
# Configuration saved in ./training_output\checkpoint-19000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-19000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-19000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-19000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-19000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-19000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-19000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-19000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-19500
# Configuration saved in ./training_output\checkpoint-19500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-19500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-19500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-19500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-19500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-19500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-19500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-19500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-20000
# Configuration saved in ./training_output\checkpoint-20000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-20000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-20000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-20000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-20000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-20000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-20000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-20000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-20500
# Configuration saved in ./training_output\checkpoint-20500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-20500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-20500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-20500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-20500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-20500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-20500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-20500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-21000
# Configuration saved in ./training_output\checkpoint-21000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-21000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-21000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-21000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-21000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-21000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-21000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-21000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-21500
# Configuration saved in ./training_output\checkpoint-21500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-21500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-21500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-21500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-21500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-21500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-21500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-21500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-22000
# Configuration saved in ./training_output\checkpoint-22000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-22000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-22000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-22000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-22000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-22000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-22000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-22000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-22500
# Configuration saved in ./training_output\checkpoint-22500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-22500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-22500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-22500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-22500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-22500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-22500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-22500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-23000
# Configuration saved in ./training_output\checkpoint-23000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-23000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-23000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-23000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-23000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-23000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-23000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-23000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-23500
# Configuration saved in ./training_output\checkpoint-23500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-23500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-23500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-23500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-23500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-23500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-23500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-23500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-24000
# Configuration saved in ./training_output\checkpoint-24000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-24000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-24000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-24000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-24000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-24000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-24000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-24000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-24500
# Configuration saved in ./training_output\checkpoint-24500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-24500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-24500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-24500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-24500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-24500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-24500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-24500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-25000
# Configuration saved in ./training_output\checkpoint-25000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-25000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-25000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-25000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-25000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-25000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-25000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-25000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-25500
# Configuration saved in ./training_output\checkpoint-25500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-25500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-25500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-25500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-25500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-25500\Helpfulness\pytorch_model_head.bin
# ...
# Configuration saved in ./training_output\checkpoint-48000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-48000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-48000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-48000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-48000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-48000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-48000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-48000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-48500
# Configuration saved in ./training_output\checkpoint-48500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-48500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-48500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-48500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-48500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-48500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-48500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-48500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-49000
# Configuration saved in ./training_output\checkpoint-49000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-49000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-49000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-49000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-49000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-49000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-49000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-49000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-49500
# Configuration saved in ./training_output\checkpoint-49500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-49500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-49500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-49500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-49500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-49500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-49500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-49500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-50000
# Configuration saved in ./training_output\checkpoint-50000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-50000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-50000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-50000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-50000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-50000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-50000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-50000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-50500
# Configuration saved in ./training_output\checkpoint-50500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-50500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-50500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-50500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-50500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-50500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-50500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-50500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-51000
# Configuration saved in ./training_output\checkpoint-51000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-51000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-51000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-51000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-51000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-51000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-51000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-51000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-51500
# Configuration saved in ./training_output\checkpoint-51500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-51500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-51500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-51500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-51500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-51500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-51500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-51500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-52000
# Configuration saved in ./training_output\checkpoint-52000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-52000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-52000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-52000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-52000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-52000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-52000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-52000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-52500
# Configuration saved in ./training_output\checkpoint-52500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-52500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-52500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-52500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-52500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-52500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-52500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-52500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-53000
# Configuration saved in ./training_output\checkpoint-53000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-53000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-53000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-53000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-53000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-53000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-53000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-53000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-53500
# Configuration saved in ./training_output\checkpoint-53500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-53500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-53500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-53500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-53500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-53500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-53500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-53500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-54000
# Configuration saved in ./training_output\checkpoint-54000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-54000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-54000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-54000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-54000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-54000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-54000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-54000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-54500
# Configuration saved in ./training_output\checkpoint-54500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-54500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-54500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-54500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-54500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-54500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-54500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-54500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-55000
# Configuration saved in ./training_output\checkpoint-55000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-55000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-55000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-55000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-55000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-55000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-55000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-55000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-55500
# Configuration saved in ./training_output\checkpoint-55500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-55500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-55500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-55500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-55500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-55500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-55500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-55500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-56000
# Configuration saved in ./training_output\checkpoint-56000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-56000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-56000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-56000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-56000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-56000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-56000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-56000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-56500
# Configuration saved in ./training_output\checkpoint-56500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-56500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-56500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-56500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-56500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-56500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-56500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-56500\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-57000
# Configuration saved in ./training_output\checkpoint-57000\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-57000\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-57000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-57000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-57000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-57000\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-57000\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-57000\Helpfulness\pytorch_model_head.bin
# Saving model checkpoint to ./training_output\checkpoint-57500
# Configuration saved in ./training_output\checkpoint-57500\Helpfulness\adapter_config.json
# Module weights saved in ./training_output\checkpoint-57500\Helpfulness\pytorch_adapter.bin
# Configuration saved in ./training_output\checkpoint-57500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-57500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-57500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-57500\Helpfulness\pytorch_model_head.bin
# Configuration saved in ./training_output\checkpoint-57500\Helpfulness\head_config.json
# Module weights saved in ./training_output\checkpoint-57500\Helpfulness\pytorch_model_head.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=57630, training_loss=0.2946141730988168, metrics={'train_runtime': 11727.7217, 'train_samples_per_second': 58.963, 'train_steps_per_second': 4.914, 'total_flos': 1.85097723416064e+17, 'train_loss': 0.2946141730988168, 'epoch': 6.0})

# %% [markdown]
# Looks good! Let's evaluate our adapter on the validation split of the dataset to see how well it learned:

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 5000
#   Batch size = 12
#     <div>
#
#       <progress value='2501' max='417' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [417/417 03:47]
#     </div>
# {'eval_loss': 0.319141685962677,
#  'eval_acc': 0.8724,
#  'eval_runtime': 37.6691,
#  'eval_samples_per_second': 132.735,
#  'eval_steps_per_second': 11.07,
#  'epoch': 6.0}

# %% [markdown]
# We can put our trained model into a `transformers` pipeline to be able to make new predictions conveniently:

# %%
# from transformers import TextClassificationPipeline

# classifier = TextClassificationPipeline(model=model, tokenizer=tokenizer, device=training_args.device.index)

# classifier("This is awesome!")

# %% [markdown]
# At last, we can also extract the adapter from our model and separately save it for later reuse. Note the size difference compared to a full model!

# %%
model.save_adapter("./final_adapter", adaptername)
# !ls -lh final_adapter
# Out:
# Configuration saved in ./final_adapter\adapter_config.json
# Module weights saved in ./final_adapter\pytorch_adapter.bin
# Configuration saved in ./final_adapter\head_config.json
# Module weights saved in ./final_adapter\pytorch_model_head.bin
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
(pred, label, metric) = trainer.predict(dataset["test"])
# Out:
# ***** Running Prediction *****
#   Num examples = 25000
#   Batch size = 12

# %%
pred_label = np.argmax(pred, axis=1)

# %%
from sklearn.metrics import classification_report

print(classification_report(label, pred_label, digits = 4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6538    0.3416    0.4487      3665
#            1     0.8955    0.9689    0.9308     21335
#
#     accuracy                         0.8770     25000
#    macro avg     0.7746    0.6553    0.6897     25000
# weighted avg     0.8600    0.8770    0.8601     25000

# %% [markdown]
# **Share your work!**
#
# The next step after training is to share our adapter with the world via _AdapterHub_. [Read our guide](https://docs.adapterhub.ml/contributing.html) on how to prepare the adapter module we just saved and contribute it to the Hub!
#
# ➡️ Also continue with [the next Colab notebook](https://colab.research.google.com/github/Adapter-Hub/adapter-transformers/blob/master/notebooks/02_Adapter_Inference.ipynb) to learn how to use adapters from the Hub.
